# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: guy muchnick
# * Student pace: self paced
# * Scheduled project review date/time: 2/4/22 4:00 pm
# * Instructor name: Abhineet Kulkarni
# * Blog post URL:https://medium.com/@guymu15/sql-and-pandas-complimenting-tools-for-data-manipulation-3851e7e9c87b

# %% [markdown]
# # Movie Performance Analysis

# %% [markdown]
# ## Overview
#
# this project analyzes the data found in the tn.movie_budgets.csv, imdb.title.basics.csv, tmdb.movies.csv regarding movies performance. descriptive analysis of the of movies production cost, income and rating.

# %% [markdown]
# ## business problem
#
# Microsoft production studios may be able to improve their investment to revenue ratio by understanding the connection between them. doing so will allow them to use their money smarter.
# Also by categorizing the data by genre Microsoft production studios can detect which genre is more profitable for them and invest their money more wisely.

# %% [markdown]
# ## data understanding
#
# our databases hold records of movies preformance since an early stage of the industry. each movie is IDed by its name and provide wide range of data about the movie.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
budget_returns = pd.read_csv('./zippedData/tn.movie_budgets.csv.gz')
basic_data = pd.read_csv('./zippedData/imdb.title.basics.csv.gz')
rating = pd.read_csv('./zippedData/tmdb.movies.csv.gz')

# %% [markdown]
# before joining our dataframes we'll need to see how the our represented,
# in the next few cells I'll present the dataframes so I'll be able to strategize their join

# %%
budget_returns
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
basic_data
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                   NaN
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %% [markdown]
# ## data cleaning

# %% [markdown]
# after seeing the structure of each dataframe i can see that the only way to join them is by movie name.
# although name is not the best option as it susceptible to changes of letter case and symbols from one side but
# is hard to clean as a movie can have a name which is symbol/case sensitive, a good example for this is the movie #horror
# that without the # won't be identifiable.

# %%
#for the first stage we'll have to join budget_returns and basic_data, both of 
#them contain vital data left join is the best choice here, as we need the 
#full data set and incomplete data won't be useable
full_monitery = budget_returns.set_index('movie').join(
    basic_data.set_index('primary_title'), how = 'left')
full_monitery
# Out:
#                             id  release_date production_budget domestic_gross  \
# #Horror                     16  Nov 20, 2015        $1,500,000             $0
# (500) Days of Summer        55  Jul 17, 2009        $7,500,000    $32,425,665
# 10 Cloverfield Lane         54  Mar 11, 2016        $5,000,000    $72,082,999
# 10 Days in a Madhouse       48  Nov 11, 2015       $12,000,000        $14,616
# 10 Things I Hate About You  63  Mar 31, 1999       $13,000,000    $38,177,966
# ...                         ..           ...               ...            ...
# mother!                     59  Sep 15, 2017       $30,000,000    $17,800,004
# xXx                         98   Aug 9, 2002       $70,000,000   $141,930,000
# xXx: Return of Xander Cage  15  Jan 20, 2017       $85,000,000    $44,898,413
# Ã l\'intÃ©rieur             57  Apr 15, 2008        $3,000,000             $0
# é·æ±ä¸è (CJ7)           2   Mar 7, 2008       $20,000,000       $206,678
#
#                            worldwide_gross     tconst  \
# #Horror                                 $0  tt3526286
# (500) Days of Summer           $34,439,060        NaN
# 10 Cloverfield Lane           $108,286,422  tt1179933
# 10 Days in a Madhouse              $14,616  tt3453052
# 10 Things I Hate About You     $60,413,950        NaN
# ...                                    ...        ...
# mother!                        $42,531,076        NaN
# xXx                           $267,200,000        NaN
# xXx: Return of Xander Cage    $345,033,359  tt1293847
# Ã l\'intÃ©rieur                   $895,932        NaN
# é·æ±ä¸è (CJ7)             $47,300,771        NaN
#
#                                         original_title  start_year  \
# #Horror                                        #Horror      2015.0
# (500) Days of Summer                               NaN         NaN
# 10 Cloverfield Lane                10 Cloverfield Lane      2016.0
# 10 Days in a Madhouse            10 Days in a Madhouse      2015.0
# 10 Things I Hate About You                         NaN         NaN
# ...                                                ...         ...
# mother!                                            NaN         NaN
# xXx                                                NaN         NaN
# xXx: Return of Xander Cage  xXx: Return of Xander Cage      2017.0
# Ã l\'intÃ©rieur                                    NaN         NaN
# é·æ±ä¸è (CJ7)                                 NaN         NaN
#
#                             runtime_minutes                     genres
# #Horror                               101.0         Crime,Drama,Horror
# (500) Days of Summer                    NaN                        NaN
# 10 Cloverfield Lane                   103.0       Drama,Horror,Mystery
# 10 Days in a Madhouse                 111.0                      Drama
# 10 Things I Hate About You              NaN                        NaN
# ...                                     ...                        ...
# mother!                                 NaN                        NaN
# xXx                                     NaN                        NaN
# xXx: Return of Xander Cage            107.0  Action,Adventure,Thriller
# Ã l\'intÃ©rieur                         NaN                        NaN
# é·æ±ä¸è (CJ7)                      NaN                        NaN
#
# [7221 rows x 10 columns]

# %%
#now we add the rating of the movies and at this point we should remove 
#duplicates, we'll use budget_returns data setas our basic data, and remove 
#conflicting data fron the other data sets.
full_monitery_and_rating = full_monitery.join(
    rating.set_index('title'),how = 'inner', rsuffix = 'r_').reset_index()
full_monitery_and_rating = full_monitery_and_rating.rename(
    columns = {'index':'title'})
full_monitery_and_rating = full_monitery_and_rating.drop_duplicates(
    subset = 'title')
full_monitery_and_rating
# Out:
#                            title  id  release_date production_budget  \
# 0                        #Horror  16  Nov 20, 2015        $1,500,000
# 1            10 Cloverfield Lane  54  Mar 11, 2016        $5,000,000
# 2          10 Days in a Madhouse  48  Nov 11, 2015       $12,000,000
# 3                      12 Strong  64  Jan 19, 2018       $35,000,000
# 4               12 Years a Slave  18  Oct 18, 2013       $20,000,000
# ...                          ...  ..           ...               ...
# 4689                 Zoolander 2  64  Feb 12, 2016       $50,000,000
# 4690                        Zoom  26  Aug 11, 2006       $35,000,000
# 4694                    Zootopia  57   Mar 4, 2016      $150,000,000
# 4695                     mother!  59  Sep 15, 2017       $30,000,000
# 4696  xXx: Return of Xander Cage  15  Jan 20, 2017       $85,000,000
#
#      domestic_gross worldwide_gross     tconst              original_title  \
# 0                $0              $0  tt3526286                     #Horror
# 1       $72,082,999    $108,286,422  tt1179933         10 Cloverfield Lane
# 2           $14,616         $14,616  tt3453052       10 Days in a Madhouse
# 3       $45,819,713     $71,118,378  tt1413492                   12 Strong
# 4       $56,671,993    $181,025,343  tt2024544            12 Years a Slave
# ...             ...             ...        ...                         ...
# 4689    $28,848,693     $55,348,693  tt1608290                 Zoolander 2
# 4690    $11,989,328     $12,506,188  tt3763866                        Zoom
# 4694   $341,268,248  $1,019,429,616  tt2948356                    Zootopia
# 4695    $17,800,004     $42,531,076        NaN                         NaN
# 4696    $44,898,413    $345,033,359  tt1293847  xXx: Return of Xander Cage
#
#       start_year  runtime_minutes                      genres  Unnamed: 0  \
# 0         2015.0            101.0          Crime,Drama,Horror       14656
# 1         2016.0            103.0        Drama,Horror,Mystery       17422
# 2         2015.0            111.0                       Drama       15907
# 3         2018.0            130.0        Action,Drama,History       24032
# 4         2013.0            134.0     Biography,Drama,History        7911
# ...          ...              ...                         ...         ...
# 4689      2016.0            101.0                      Comedy       17483
# 4690      2015.0             96.0      Animation,Comedy,Drama       18195
# 4694      2016.0            108.0  Adventure,Animation,Comedy       17391
# 4695         NaN              NaN                         NaN       20707
# 4696      2017.0            107.0   Action,Adventure,Thriller       20651
#
#                 genre_ids    idr_ original_language  \
# 0      [18, 9648, 27, 53]  301325                de
# 1           [53, 878, 18]  333371                en
# 2                    [18]  345003                en
# 3     [10752, 18, 36, 28]  429351                en
# 4                [18, 36]   76203                en
# ...                   ...     ...               ...
# 4689                 [35]  329833                en
# 4690         [16, 35, 18]  351065                en
# 4694  [16, 12, 10751, 35]  269149                en
# 4695       [18, 27, 9648]  381283                en
# 4696         [28, 12, 80]   47971                en
#
#                 original_titler_  popularity release_dater_  vote_average  \
# 0                        #Horror       6.099     2015-11-20           3.3
# 1            10 Cloverfield Lane      17.892     2016-03-11           6.9
# 2          10 Days in a Madhouse       0.955     2015-11-20           5.4
# 3                      12 Strong      13.183     2018-01-19           5.6
# 4               12 Years a Slave      16.493     2013-10-30           7.9
# ...                          ...         ...            ...           ...
# 4689                 Zoolander 2      12.997     2016-02-12           4.7
# 4690                        Zoom       3.434     2016-09-02           5.5
# 4694                    Zootopia      27.549     2016-03-04           7.7
# 4695                     mother!      15.227     2017-09-15           7.0
# 4696  xXx: Return of Xander Cage      21.749     2017-01-20           5.6
#
#       vote_count
# 0            102
# 1           4629
# 2              7
# 3           1312
# 4           6631
# ...          ...
# 4689        1374
# 4690          43
# 4694        9977
# 4695        3458
# 4696        2452
#
# [1924 rows x 20 columns]

# %%
#we don't need all the included data, some of it is duplicate from different 
#datasets and some is just not usefull for us.
cleared_data = full_monitery_and_rating.drop(
    full_monitery_and_rating.columns.difference(
    ['title','production_budget','worldwide_gross','genres','vote_average']),
    1)
cleared_data
# Out:
#                            title production_budget worldwide_gross  \
# 0                        #Horror        $1,500,000              $0
# 1            10 Cloverfield Lane        $5,000,000    $108,286,422
# 2          10 Days in a Madhouse       $12,000,000         $14,616
# 3                      12 Strong       $35,000,000     $71,118,378
# 4               12 Years a Slave       $20,000,000    $181,025,343
# ...                          ...               ...             ...
# 4689                 Zoolander 2       $50,000,000     $55,348,693
# 4690                        Zoom       $35,000,000     $12,506,188
# 4694                    Zootopia      $150,000,000  $1,019,429,616
# 4695                     mother!       $30,000,000     $42,531,076
# 4696  xXx: Return of Xander Cage       $85,000,000    $345,033,359
#
#                           genres  vote_average
# 0             Crime,Drama,Horror           3.3
# 1           Drama,Horror,Mystery           6.9
# 2                          Drama           5.4
# 3           Action,Drama,History           5.6
# 4        Biography,Drama,History           7.9
# ...                          ...           ...
# 4689                      Comedy           4.7
# 4690      Animation,Comedy,Drama           5.5
# 4694  Adventure,Animation,Comedy           7.7
# 4695                         NaN           7.0
# 4696   Action,Adventure,Thriller           5.6
#
# [1924 rows x 5 columns]

# %%
#let's see if we have na in our data
cleared_data.isna().sum()
# Out:
# title                  0
# production_budget      0
# worldwide_gross        0
# genres               146
# vote_average           0
# dtype: int64

# %%
#as genre data cant be used in a statistical way we have no real option but 
#removing those movies as we lack data on them
cleared_data.dropna(inplace = True)
cleared_data.isna().sum()
# Out:
# title                0
# production_budget    0
# worldwide_gross      0
# genres               0
# vote_average         0
# dtype: int64

# %%
cleared_data['production_budget'] = cleared_data['production_budget'].str.replace(
    '$','').str.replace(',','').astype('int64')
cleared_data['worldwide_gross'] = cleared_data['worldwide_gross'].str.replace(
    '$','').str.replace(',','').astype('int64')
cleared_data
# Out:
#                            title  production_budget  worldwide_gross  \
# 0                        #Horror            1500000                0
# 1            10 Cloverfield Lane            5000000        108286422
# 2          10 Days in a Madhouse           12000000            14616
# 3                      12 Strong           35000000         71118378
# 4               12 Years a Slave           20000000        181025343
# ...                          ...                ...              ...
# 4688                   Zookeeper           80000000        170805525
# 4689                 Zoolander 2           50000000         55348693
# 4690                        Zoom           35000000         12506188
# 4694                    Zootopia          150000000       1019429616
# 4696  xXx: Return of Xander Cage           85000000        345033359
#
#                           genres  vote_average
# 0             Crime,Drama,Horror           3.3
# 1           Drama,Horror,Mystery           6.9
# 2                          Drama           5.4
# 3           Action,Drama,History           5.6
# 4        Biography,Drama,History           7.9
# ...                          ...           ...
# 4688       Comedy,Family,Romance           5.3
# 4689                      Comedy           4.7
# 4690      Animation,Comedy,Drama           5.5
# 4694  Adventure,Animation,Comedy           7.7
# 4696   Action,Adventure,Thriller           5.6
#
# [1778 rows x 5 columns]

# %%
cleared_data.drop(
    cleared_data.loc[cleared_data['worldwide_gross']==0].index, inplace=True)

# %% [markdown]
# ## general revenue per investment

# %% [markdown]
# let's try and see how a scatter plot of revenue per investment will look like and if we  an notice any
# obvious trends

# %%
fig1, ax1 = plt.subplots(figsize=(15,5))
ax1.scatter(
    cleared_data["production_budget"], 
    cleared_data["worldwide_gross"], color="green");
ax1.ticklabel_format(style='plain')
ax1.set_ylim(ymin=0)
ax1.set_xlim(xmin=0)
ax1.set_title("Gross revenues vs Investment")
ax1.set_xlabel("investment $")
ax1.set_ylabel("Gross revenues $");
plt.savefig("graphs\Gross_revenues_vs_Investment.png",
            bbox_inches='tight', dpi=600)

# %% [markdown]
# the only discernible trend is that most movies investments are less than 100,000,000$ and most of the gross revenues for those movies are under 5,000,000,000

# %%
cleared_data["production_budget"].agg(['count', 'median', 'mean','min','max'])
# Out:
# count     1.632000e+03
# median    2.200000e+07
# mean      4.247776e+07
# min       9.000000e+03
# max       4.250000e+08
# Name: production_budget, dtype: float64

# %%
cleared_data["worldwide_gross"].agg(['count', 'median', 'mean','min','max'])
# Out:
# count     1.632000e+03
# median    4.661594e+07
# mean      1.333133e+08
# min       2.600000e+01
# max       2.776345e+09
# Name: worldwide_gross, dtype: float64

# %%
cleared_data['value_per_investment'] = (cleared_data['worldwide_gross'] /
                                        cleared_data['production_budget'])
cleared_data
# Out:
#                            title  production_budget  worldwide_gross  \
# 1            10 Cloverfield Lane            5000000        108286422
# 2          10 Days in a Madhouse           12000000            14616
# 3                      12 Strong           35000000         71118378
# 4               12 Years a Slave           20000000        181025343
# 5                      127 Hours           18000000         60217171
# ...                          ...                ...              ...
# 4688                   Zookeeper           80000000        170805525
# 4689                 Zoolander 2           50000000         55348693
# 4690                        Zoom           35000000         12506188
# 4694                    Zootopia          150000000       1019429616
# 4696  xXx: Return of Xander Cage           85000000        345033359
#
#                           genres  vote_average  value_per_investment
# 1           Drama,Horror,Mystery           6.9             21.657284
# 2                          Drama           5.4              0.001218
# 3           Action,Drama,History           5.6              2.031954
# 4        Biography,Drama,History           7.9              9.051267
# 5      Adventure,Biography,Drama           7.0              3.345398
# ...                          ...           ...                   ...
# 4688       Comedy,Family,Romance           5.3              2.135069
# 4689                      Comedy           4.7              1.106974
# 4690      Animation,Comedy,Drama           5.5              0.357320
# 4694  Adventure,Animation,Comedy           7.7              6.796197
# 4696   Action,Adventure,Thriller           5.6              4.059216
#
# [1632 rows x 6 columns]

# %%
cleared_data["vote_average"].agg(['count', 'median', 'mean','min','max'])
# Out:
# count     1632.000000
# median       6.300000
# mean         6.257782
# min          0.000000
# max         10.000000
# Name: vote_average, dtype: float64

# %%
cleared_data["value_per_investment"].agg(
    ['count', 'median', 'mean','min','max'])
# Out:
# count     1632.000000
# median       2.075969
# mean         3.885146
# min          0.000026
# max        416.564740
# Name: value_per_investment, dtype: float64

# %% [markdown]
# ## relations between rating and revenues
# after organizing the required data we can now try and find a trend connecting rating and value per investment.

# %%
vote_vpi_mean = cleared_data["value_per_investment"].groupby(
    cleared_data["vote_average"]).agg(['mean'])
vote_vpi_mean = vote_vpi_mean.reset_index()
fig, ax = plt.subplots(figsize=(15,5))
ax.bar(round(vote_vpi_mean["vote_average"]),vote_vpi_mean["mean"],color = 'blue')
ax.set_title("rating per value per investment")
ax.set_xlabel("rating")
ax.set_ylabel("mean value per investment");
plt.savefig("graphs\Rating_per_value_per_investment.png")

# %% [markdown]
# As we can see in the bar plot above there doesn't seem to be any trend connecting rating and value per investment.

# %%
fig2, ax2 = plt.subplots(figsize=(15,5))
bins1 = range(int(cleared_data["value_per_investment"].min()), 
             int(cleared_data["value_per_investment"].max()))
ax2.hist(
    x = cleared_data["value_per_investment"],
    bins = bins1,
    color = 'green')
ax2.set_xlim(xmin=0)
ax2.set_title("General Gross revenues Per Investment")
ax2.set_xlabel(" Gross revenues Per Investment")
ax2.set_ylabel("Count of Movies");
plt.savefig("graphs\General_Gross_revenues_Per_Investment.png",
            bbox_inches='tight', dpi=600)

# %%
fig2, ax2 = plt.subplots(figsize=(15,5))
bins1 = range(int(cleared_data["value_per_investment"].min()), 
             int(cleared_data["value_per_investment"].max()))
ax2.hist(
    x = cleared_data["value_per_investment"],
    bins = bins1,
    color = 'green')
ax2.set_xlim(xmin=0,xmax=120)
ax2.set_title("General Gross revenues Per Investment (max value reduced)")
ax2.set_xlabel(" Gross revenues Per Investment")
ax2.set_ylabel("Count of Movies");
plt.savefig("graphs\General_Gross_revenues_Per_Investment_(max_value_reduced).png",
            bbox_inches='tight', dpi=600)

# %% [markdown]
# ## general rating per investment

# %%
cleared_data[cleared_data["value_per_investment"] < 1]
# Out:
#                       title  production_budget  worldwide_gross  \
# 2     10 Days in a Madhouse           12000000            14616
# 7                   13 Sins            4000000            47552
# 16                 23 Blast            1000000           549185
# 17                        3            7200000           295492
# 23              3 Backyards             300000            39475
# ...                     ...                ...              ...
# 4622        Won't Back Down           19000000          5745503
# 4655      Wuthering Heights            8000000          2721534
# 4660            Yoga Hosers            5000000            22958
# 4666          Your Highness           50000000         26121638
# 4690                   Zoom           35000000         12506188
#
#                         genres  vote_average  value_per_investment
# 2                        Drama           5.4              0.001218
# 7              Horror,Thriller           6.3              0.011888
# 16          Drama,Family,Sport           6.5              0.549185
# 17        Comedy,Drama,Romance           6.0              0.041041
# 23                       Drama           4.3              0.131583
# ...                        ...           ...                   ...
# 4622                     Drama           6.3              0.302395
# 4655             Drama,Romance           6.1              0.340192
# 4660     Action,Comedy,Fantasy           4.5              0.004592
# 4666  Adventure,Comedy,Fantasy           3.0              0.522433
# 4690    Animation,Comedy,Drama           5.5              0.357320
#
# [486 rows x 6 columns]

# %%
cleared_data['rating_per_investment'] = (cleared_data['vote_average'] /
                                        (cleared_data['production_budget']/
                                        1000000))
cleared_data
# Out:
#                            title  production_budget  worldwide_gross  \
# 1            10 Cloverfield Lane            5000000        108286422
# 2          10 Days in a Madhouse           12000000            14616
# 3                      12 Strong           35000000         71118378
# 4               12 Years a Slave           20000000        181025343
# 5                      127 Hours           18000000         60217171
# ...                          ...                ...              ...
# 4688                   Zookeeper           80000000        170805525
# 4689                 Zoolander 2           50000000         55348693
# 4690                        Zoom           35000000         12506188
# 4694                    Zootopia          150000000       1019429616
# 4696  xXx: Return of Xander Cage           85000000        345033359
#
#                           genres  vote_average  value_per_investment  \
# 1           Drama,Horror,Mystery           6.9             21.657284
# 2                          Drama           5.4              0.001218
# 3           Action,Drama,History           5.6              2.031954
# 4        Biography,Drama,History           7.9              9.051267
# 5      Adventure,Biography,Drama           7.0              3.345398
# ...                          ...           ...                   ...
# 4688       Comedy,Family,Romance           5.3              2.135069
# 4689                      Comedy           4.7              1.106974
# 4690      Animation,Comedy,Drama           5.5              0.357320
# 4694  Adventure,Animation,Comedy           7.7              6.796197
# 4696   Action,Adventure,Thriller           5.6              4.059216
#
#       rating_per_investment
# 1                  1.380000
# 2                  0.450000
# 3                  0.160000
# 4                  0.395000
# 5                  0.388889
# ...                     ...
# 4688               0.066250
# 4689               0.094000
# 4690               0.157143
# 4694               0.051333
# 4696               0.065882
#
# [1632 rows x 7 columns]

# %%
fig1, ax3 = plt.subplots(figsize=(15,5))
ax3.scatter(
    cleared_data["production_budget"], 
    cleared_data["vote_average"], color="blue");
ax3.ticklabel_format(style='plain')
ax3.set_ylim(ymin=0)
ax3.set_xlim(xmin=0)
ax3.set_title("Rating vs Investment")
ax3.set_xlabel("Investment")
ax3.set_ylabel("Rating");
plt.savefig("graphs\Rating_vs_Investment.png",
            bbox_inches='tight', dpi=600)

# %%
cleared_data["vote_average"].agg(
    ['count', 'median', 'mean','min','max'])
# Out:
# count     1632.000000
# median       6.300000
# mean         6.257782
# min          0.000000
# max         10.000000
# Name: vote_average, dtype: float64

# %% [markdown]
# by seeing the scatter plot and checking the median we can see that the more we invest the movies tend to get
# the same rating and the most spread we see is on small investments.

# %%
cleared_data["rating_per_investment"].agg(
    ['count', 'median', 'mean','min','max'])
# Out:
# count     1632.000000
# median       0.272111
# mean         2.644860
# min          0.000000
# max        600.000000
# Name: rating_per_investment, dtype: float64

# %%
fig4, ax4 = plt.subplots(figsize=(15,5))
ax4.hist(
    x = cleared_data["rating_per_investment"], log = False)
ax4.set_xlim(xmin=0)
ax4.set_title("General Rating Per Investment")
ax4.set_xlabel("Rating Per Investment(million dollars to 1 star)")
ax4.set_ylabel("Count of Movies");
plt.savefig("graphs\Rating Per_Investment(million_dollars_to_1_star).png",
            bbox_inches='tight', dpi=600)

# %% [markdown]
# as we can see here, there is not much change in the rating per investment as the magnitude of the investment dwarfs the
# rating scale.

# %%
cleared_data["genres"].value_counts()
# Out:
# Drama                         89
# Adventure,Animation,Comedy    61
# Comedy,Drama,Romance          61
# Comedy,Drama                  56
# Comedy                        53
#                               ..
# Adventure,Comedy,Romance       1
# Drama,Music,Musical            1
# Adventure,Biography,Comedy     1
# Adventure,Comedy,Music         1
# Documentary,War                1
# Name: genres, Length: 252, dtype: int64

# %% [markdown]
# ## dividing into genres

# %%
# in order to split each genre cell to indevidual genres i have used a 
# function i found here https://www.py4u.net/discuss/11964
cleared_data_gsplit = (cleared_data.set_index(
    ['title','production_budget','worldwide_gross','vote_average',
    'value_per_investment','rating_per_investment'])
   .apply(lambda x: x.str.split(',').explode())
   .reset_index())                                                   
cleared_data_gsplit
# Out:
#                            title  production_budget  worldwide_gross  \
# 0            10 Cloverfield Lane            5000000        108286422
# 1            10 Cloverfield Lane            5000000        108286422
# 2            10 Cloverfield Lane            5000000        108286422
# 3          10 Days in a Madhouse           12000000            14616
# 4                      12 Strong           35000000         71118378
# ...                          ...                ...              ...
# 4032                    Zootopia          150000000       1019429616
# 4033                    Zootopia          150000000       1019429616
# 4034  xXx: Return of Xander Cage           85000000        345033359
# 4035  xXx: Return of Xander Cage           85000000        345033359
# 4036  xXx: Return of Xander Cage           85000000        345033359
#
#       vote_average  value_per_investment  rating_per_investment     genres
# 0              6.9             21.657284               1.380000      Drama
# 1              6.9             21.657284               1.380000     Horror
# 2              6.9             21.657284               1.380000    Mystery
# 3              5.4              0.001218               0.450000      Drama
# 4              5.6              2.031954               0.160000     Action
# ...            ...                   ...                    ...        ...
# 4032           7.7              6.796197               0.051333  Animation
# 4033           7.7              6.796197               0.051333     Comedy
# 4034           5.6              4.059216               0.065882     Action
# 4035           5.6              4.059216               0.065882  Adventure
# 4036           5.6              4.059216               0.065882   Thriller
#
# [4037 rows x 7 columns]

# %%
cleared_data_gsplit["genres"].value_counts()
# Out:
# Drama          825
# Comedy         526
# Action         433
# Adventure      342
# Thriller       275
# Crime          241
# Romance        213
# Horror         194
# Biography      145
# Sci-Fi         138
# Mystery        127
# Fantasy        125
# Animation      101
# Family          94
# Documentary     78
# History         54
# Music           49
# Sport           36
# War             21
# Western         11
# Musical          8
# News             1
# Name: genres, dtype: int64

# %%
cleared_data_gsplit.to_csv('./zippedData/cleared_data_gsplit.csv')

# %% [markdown]
# after dividing the data the separate genres let try and extract some statistical data, which genre will be most profitable on average? what genre has the biggest max revenue ratio?

# %%
# !pip install pandasql
# Out:
# Requirement already satisfied: pandasql in c:\users\guymu\.conda\envs\learn-env\lib\site-packages (0.7.3)
# Requirement already satisfied: sqlalchemy in c:\users\guymu\.conda\envs\learn-env\lib\site-packages (from pandasql) (1.3.19)
# Requirement already satisfied: pandas in c:\users\guymu\.conda\envs\learn-env\lib\site-packages (from pandasql) (1.1.3)
# Requirement already satisfied: numpy in c:\users\guymu\.conda\envs\learn-env\lib\site-packages (from pandasql) (1.18.5)
# Requirement already satisfied: pytz>=2017.2 in c:\users\guymu\.conda\envs\learn-env\lib\site-packages (from pandas->pandasql) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\guymu\.conda\envs\learn-env\lib\site-packages (from pandas->pandasql) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\guymu\.conda\envs\learn-env\lib\site-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)

# %%
from pandasql import sqldf

# %% [markdown]
# ## genres revenue per investment

# %%
q1 = """SELECT genres, AVG(value_per_investment), COUNT(title)
       FROM cleared_data_gsplit
       GROUP BY genres
       ORDER BY  AVG(value_per_investment) DESC;"""
vpi = sqldf(q1,locals())
vpi
# Out:
#          genres  AVG(value_per_investment)  COUNT(title)
# 0       Mystery                  10.372646           127
# 1        Horror                   9.212387           194
# 2      Thriller                   6.720030           275
# 3          News                   3.894215             1
# 4     Animation                   3.856477           101
# 5       Romance                   3.811516           213
# 6        Sci-Fi                   3.550328           138
# 7     Biography                   3.387715           145
# 8        Comedy                   3.379373           526
# 9         Music                   3.355817            49
# 10        Sport                   3.284208            36
# 11       Family                   3.224272            94
# 12    Adventure                   3.203349           342
# 13      Fantasy                   3.147515           125
# 14        Drama                   3.145232           825
# 15  Documentary                   3.090244            78
# 16       Action                   2.918489           433
# 17        Crime                   2.366236           241
# 18      History                   2.099533            54
# 19      Musical                   1.856923             8
# 20      Western                   1.756450            11
# 21          War                   1.391384            21

# %%
fig5, ax5 = plt.subplots(figsize=(15,5))
ax5.barh(
    vpi['genres'], 
    vpi["AVG(value_per_investment)"],
    color = 'green')
ax5.set_title("Genre's Gross revenues Per Investment")
ax5.set_xlabel("Average Gross revenues Per Investment")
ax5.set_ylabel("Genre");
plt.savefig("graphs\Genre's_Gross_Income_Per_Investment.png",
            bbox_inches='tight', dpi=600)

# %% [markdown]
# it's apparent that some genres give better value for their investment, the best value, which is visible in the bar plot above , are mystery, horror and thriller, so its safe to assume that if we made a movie from any of those genres or even all of them together we will get to best revenues for our investment.

# %% [markdown]
# ## genres rating per investment

# %%
q2 = """SELECT genres, AVG(rating_per_investment), COUNT(title)
       FROM cleared_data_gsplit
       GROUP BY genres
       ORDER BY  AVG(rating_per_investment) DESC;"""
rpi = sqldf(q2,locals())
rpi
# Out:
#          genres  AVG(rating_per_investment)  COUNT(title)
# 0   Documentary                    6.971735            78
# 1       Mystery                    3.953758           127
# 2        Horror                    3.658767           194
# 3         Drama                    3.451947           825
# 4        Comedy                    2.684111           526
# 5       Romance                    2.649359           213
# 6      Thriller                    2.109479           275
# 7         Sport                    2.094665            36
# 8         Music                    1.933999            49
# 9        Sci-Fi                    1.597501           138
# 10      History                    1.337111            54
# 11      Fantasy                    1.268507           125
# 12      Western                    1.210163            11
# 13        Crime                    1.121911           241
# 14          War                    1.115155            21
# 15    Biography                    0.985389           145
# 16      Musical                    0.943469             8
# 17       Family                    0.941942            94
# 18         News                    0.450000             1
# 19       Action                    0.422570           433
# 20    Adventure                    0.298661           342
# 21    Animation                    0.116989           101

# %%
fig6, ax6 = plt.subplots(figsize=(15,5))
ax6.barh(
    rpi['genres'], 
    rpi["AVG(rating_per_investment)"],
    color = 'blue')
ax6.set_title("Genre's Rating Per Investment")
ax6.set_xlabel("Average Rating Per Investment (million dollars per star)")
ax6.set_ylabel("Genre");
plt.savefig("graphs\Genre's_Rating_Per_Investment.png",
            bbox_inches='tight', dpi=600)

# %% [markdown]
# we can see that documentary movies tend to get the best rating for their investment which is not consistent with our observations from the revenues for investment plot. although we have this inconsistency we can see that the 2 categories that come after are the 2 most profitable ones from what we have seen before.

# %% [markdown]
# ## conclusions
# from the data we analyzed we can see that the genres that will get Microsoft production studios the best value for their investment are mystery and horror, they have the best revenues for investment and also have high rating for investment.
# in case Microsoft production studios would be interested in prioritizing rating over revenues it'd be better to make a documentary or at least add a documentary element to it.
# on the other end if they prioritize revenues over rating adding thriller elements to our movie would be advisable.

# %% [markdown]
# ## next steps
#
# further analysis could improve our conclusions and allow us to make additional observations:
#  - **using additional databases in order to validate our data.** by using only one data source we risk it being wrong, by using additional sources we eliminate the problem.
#  - **checking the effects of additional Variables on revenues.** we can check additional data in the field, do specific actors affect the revenue? do they affect it only in specific genres? are there specific dates that affect revenue? and so on.
#  - **checking the trends in the long term past.** by doing this we can see if there is a recurring trends, Perhaps there are cycles of popularity, or even genres of movies that get better revenues only after certain amount of time.
